# %%
from Benchmarks import ARCH_benchmarks
from TERA.Workbench.Task import TaskRunner
from TERA.Workbench.Report import Report
from TERA.Workbench.Visualizer import Visualizer
from TERA.TMCore.Interval import Interval

arch_2020 = ARCH_benchmarks.get_arch_hybrid_2020()

# %% [markdown]
# ## 2020 Lotka Volterra w/ Crossings

# %%
task = arch_2020["arch20_hybrid_lovo20"]
result = TaskRunner.run(task, progress_bar=True)

mode_colors = {'outside': 'magenta', 'inside': 'blue'}
plot = Visualizer.plot(result, dims=(0, 1), mode="phase", mode_colors=mode_colors, title="Lotka Volterra (With Crossings): x vs y", filled=True)
plot = Visualizer.plot(result, y_idx=2, mode="time", title="Lotka Volterra (With Crossings): cnt vs t", filled=True)
# Out:
# [TaskRunner] Initializing hybrid task: Lotka-Volterra Crossing (ARCH 2020)
# [TaskRunner] Hybrid initial-set splitting active: produced 5 initial box(es).
# Hybrid Reachability Analysis:   0%|          | 0/3.64 [00:00<?, ?it/s]
# ...
# --- Starting HYBRID Test: Lotka-Volterra Crossing (ARCH 2020) ---
# Mode: single_step
# System: None
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([1.29200000000000, 1.30800000000001]), Interval([1.00000000000000, 1.00000000000000]), Interval([0.000000000000000, -0.000000000000000])]
# Time: [0, 3.64], Step: 0.01, Order: 3
# Hybrid Config: Max Jumps=10, Methods: Intersection=domain_contraction, Aggregation=PCA
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 116.7758 seconds
# Computed 1808 segments.
# ----------------------------------------------------------------------
# Hybrid Path Summary:
#   Total Segments: 1808
#   Modes Traversed: inside, outside
# ...

# %% [markdown]
# ## 2020 Space Rendezvouz

# %%
task = arch_2020["arch20_hybrid_space_rendezvous"]
result = TaskRunner.run(task, progress_bar=True)

mode_colors = {'approaching': 'blue', 'rendezvouz_attempt': 'red', 'aborting': 'green'}
plot = Visualizer.plot(result, dims=(0, 1), mode="phase", mode_colors=mode_colors, title="Space Rendezvouz: x vs y", filled=True)
plot = Visualizer.plot(result, y_idx=2, mode="time", title="Lotka Volterra (With Crossings): cnt vs t", filled=True)
