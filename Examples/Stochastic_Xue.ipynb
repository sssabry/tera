# %%
from Benchmarks import Xue_benchmarks
from TERA.Workbench.Task import TaskRunner
from TERA.Workbench.Visualizer import Visualizer

xue = Xue_benchmarks.get_benchmarks()

# %%
task = xue["xue_pop_growth_case1"]
result = TaskRunner.run(task, progress_bar=True)
plot = Visualizer.plot(result, title="Population Growth Model: Case 1")
# Out:
# [TaskRunner] Initializing stochastic task: Population Growth Model Case 1 (Xue Example 1.1)
# Reachability Analysis:   0%|          | 0/100.0 [00:00<?, ?it/s]
# [Monte Carlo] Simulating 1000 traces (0.0->100.0) with dt=0.001...
#
# ...
# --- Starting STOCHASTIC Test: Population Growth Model Case 1 (Xue Example 1.1) ---
# Mode: single_step
# System: [-x]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([-0.800000000000001, -0.800000000000000])]
# Time: [0, 100.0], Step: 0.1, Order: 4
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 6.2345 seconds
# Computed 225 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# ...

# %%
task = xue["xue_pop_growth_case2"]
result = TaskRunner.run(task, progress_bar=True)
plot = Visualizer.plot(result, title="Population Growth Model: Case 2")
# Out:
# [TaskRunner] Initializing stochastic task: Population Growth Model Case 2 (Xue Example 1.2)
# Reachability Analysis:   0%|          | 0/1.0 [00:00<?, ?it/s]
# [Monte Carlo] Simulating 10000 traces (0.0->1.0) with dt=0.001...
#
# ...
# --- Starting STOCHASTIC Test: Population Growth Model Case 2 (Xue Example 1.2) ---
# Mode: single_step
# System: [-10.0*x]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([-0.800000000000001, -0.800000000000000])]
# Time: [0, 1.0], Step: 0.02, Order: 4
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 0.5997 seconds
# Computed 28 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# ...

# %%
task = xue["xue_pop_growth_case3"]
result = TaskRunner.run(task, progress_bar=True)
plot = Visualizer.plot(result, title="Population Growth Model: Case 3")
# Out:
# [TaskRunner] Initializing stochastic task: Population Growth Model Case 3 (Xue Example 1.3)
# Reachability Analysis:   0%|          | 0/10.0 [00:00<?, ?it/s]
# [Monte Carlo] Simulating 10000 traces (0.0->10.0) with dt=0.001...
#
# ...
# --- Starting STOCHASTIC Test: Population Growth Model Case 3 (Xue Example 1.3) ---
# Mode: single_step
# System: [-x + 0.1]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([-0.500000000000000, -0.500000000000000])]
# Time: [0, 10.0], Step: 0.05, Order: 4
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 4.0133 seconds
# Computed 56 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# ...

# %%
task = xue["xue_poly_2d"]
result = TaskRunner.run(task, progress_bar=True)
plot = Visualizer.plot(result, title="Polynomial 2D")
# Out:
# [TaskRunner] Initializing stochastic task: 2D Polynomial SDE (Xue Example 2)
# Reachability Analysis:   0%|          | 0/1.0 [00:00<?, ?it/s]
# [Monte Carlo] Simulating 10000 traces (0.0->1.0) with dt=0.001...
#
# ...
# --- Starting STOCHASTIC Test: 2D Polynomial SDE (Xue Example 2) ---
# Mode: single_step
# System: [-x + 1, x + 10.0*y]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([-0.500000000000000, -0.500000000000000]), Interval([0.500000000000000, 0.500000000000000])]
# Time: [0, 1.0], Step: 0.02, Order: 4
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 1.5126 seconds
# Computed 50 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ...
