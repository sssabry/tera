# %%
from Benchmarks import AMGF_benchmarks
from TERA.Workbench.Task import TaskRunner
from TERA.Workbench.Visualizer import Visualizer

AMGF = AMGF_benchmarks.get_AMGF_benchmarks()

# %% [markdown]
# ## Textbooks

# %%
from Benchmarks import textbook_benchmarks
BOOK = textbook_benchmarks.get_textbook_benchmarks()

# %%
task_vdp = BOOK["stoch_duffing_vdp"]
task_vdp.engine_params.update({'delta': 0.1})
result_vdp = TaskRunner.run(task_vdp)
plot = Visualizer.plot(result_vdp, title="Stochastic Duffing Van Der Pol (1k traces)", show_axis_bound_overlay=True)
# Out:
# [TaskRunner] Initializing stochastic task: Stochastic Duffing-Van der Pol (Sarkka & Solin 2019, Ex. 8.15)
# [Monte Carlo] Simulating 2000 traces (0.0->20.0) with dt=0.001...
#
# ======================================================================
# --- Starting STOCHASTIC Test: Stochastic Duffing-Van der Pol (Sarkka & Solin 2019, Ex. 8.15) ---
# Mode: single_step
# System: [x2, -(x1^2 - 1.0)*x1 - x2]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([0.900000000000000, 1.10000000000001]), Interval([-0.100000000000001, 0.100000000000001])]
# Time: [0, 20.0], Step: 0.02, Order: 4
# Stochastic Config: Delta=0.100000000000000
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 17.2572 seconds
# Computed 1001 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# x1         | [   0.90000,    1.10000]       | [  -5.19931,    7.19931]
# x2         | [  -0.10000,    0.10000]       | [  -9.54901,    9.54901]
#
# Validation Statistics
# Metric: max_k ||L (X_t^k - x_t^k)|| (paired deterministic trajectories, weighted)
#   Status: PASS
#   Max Theoretical Bound (r): 7.216799
#   Max Empirical Deviation:   3.675269
#   Safety Margin:             3.541530
#   Trajectory Violations:     0 steps had outliers (100% enclosed at sampled times)
# ======================================================================
#
# [Plotter] Generating Weighted Minkowski Envelopes...

# %%
task_vdp = BOOK["stoch_spring_model"]
result_vdp = TaskRunner.run(task_vdp)
plot = Visualizer.plot(result_vdp, title="Stochastic Spring Model", show_axis_bound_overlay=True)
# Out:
# [TaskRunner] Initializing stochastic task: Spring Model (Sarkka & Solin 2019, Ex. 6.6, Eq. 6.47)
# [Monte Carlo] Simulating 2000 traces (0.0->20.0) with dt=0.001...
#
# ======================================================================
# --- Starting STOCHASTIC Test: Spring Model (Sarkka & Solin 2019, Ex. 6.6, Eq. 6.47) ---
# Mode: single_step
# System: [x2, -1.0*x1 - 0.1*x2]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([0.900000000000000, 1.10000000000001]), Interval([-0.100000000000001, 0.100000000000001])]
# Time: [0, 20.0], Step: 0.02, Order: 4
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 10.8948 seconds
# Computed 1001 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# x1         | [   0.07510,    0.27510]       | [ -17.00842,   17.35862]
# x2         | [  -0.43241,   -0.23241]       | [ -17.55858,   16.89376]
#
# Validation Statistics
# Metric: max_k ||L (X_t^k - x_t^k)|| (paired deterministic trajectories, weighted)
#   Status: PASS
#   Max Theoretical Bound (r): 54.090309
#   Max Empirical Deviation:   30.297271
#   Safety Margin:             23.793038
#   Trajectory Violations:     0 steps had outliers (100% enclosed at sampled times)
# ======================================================================
#
# [Plotter] Generating Weighted Minkowski Envelopes...
