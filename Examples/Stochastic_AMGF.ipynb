# %%
from Benchmarks import AMGF_benchmarks
from TERA.Workbench.Task import TaskRunner
from TERA.Workbench.Visualizer import Visualizer

AMGF = AMGF_benchmarks.get_AMGF_benchmarks()

# %% [markdown]
# ## 2025 TAC Paper

# %%
task_lin = AMGF["amgf_stoch_linear"]
result_lin = TaskRunner.run(task_lin)
plot = Visualizer.plot(result_lin, title="Linear 1D (2000 Traces)")
# Out:
# [TaskRunner] Initializing stochastic task: AMGF Linear 1D (mu(A)=-0.4, sigma=sqrt(2))
# [Monte Carlo] Simulating 5000 traces (0.0->1.5) with dt=0.001...
# /home/ssabry/diss/dissertation/development/TERA/Stochastic/StochasticReach.py:28: RuntimeWarning: g_exprs provided as 1D list; interpreting as diagonal (legacy behavior).
#   warnings.warn(
# ======================================================================
# --- Starting STOCHASTIC Test: AMGF Linear 1D (mu(A)=-0.4, sigma=sqrt(2)) ---
# Mode: single_step
# System: [-0.4*x]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([0.000000000000000, -0.000000000000000])]
# Time: [0, 1.5], Step: 0.05, Order: 4
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 0.3317 seconds
# Computed 11 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# x          | [  -0.00000,    0.00000]       | [  -8.42772,    8.42772]
#
# Validation Statistics
# Metric: max_k ||X_t^k - x_t^k|| (paired deterministic trajectories)
#   Status: PASS
#   Max Theoretical Bound (r): 8.427718
#   Max Empirical Deviation:   5.499968
#   Safety Margin:             2.927750
#   Trajectory Violations:     0 steps had outliers (100% enclosed at sampled times)
# ======================================================================
#
# [Plotter] Generating Euclidean Minkowski Envelopes...

# %%
task_pend_ss = AMGF["stoch_pendulum"]
result_pend_ss = TaskRunner.run(task_pend_ss)
plot = Visualizer.plot(result_pend_ss, title="Pendulum: Single Step Adaptive")
# Out:
# [TaskRunner] Initializing stochastic task: Inverted Pendulum
# [Monte Carlo] Simulating 2000 traces (0.0->4.0) with dt=0.001...
#
# ======================================================================
# --- Starting STOCHASTIC Test: Inverted Pendulum ---
# Mode: single_step
# System: [omega, -20.0*omega - 20.0*theta + 10.0*sin(theta)]
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([-0.314159265358980, 0.314159265358980]), Interval([-0.200000000000001, 0.200000000000001])]
# Time: [0, 4.0], Step: 0.05, Order: 4
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 5.4892 seconds
# Computed 320 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# theta      | [  -0.31728,    0.31728]       | [  -0.52002,    0.52002]
# omega      | [  -0.30215,    0.30215]       | [  -1.37677,    1.37677]
#
# Validation Statistics
# Metric: max_k ||L (X_t^k - x_t^k)|| (paired deterministic trajectories, weighted)
#   Status: PASS
#   Max Theoretical Bound (r): 1.143908
#   Max Empirical Deviation:   0.122434
#   Safety Margin:             1.021474
#   Trajectory Violations:     0 steps had outliers (100% enclosed at sampled times)
# ======================================================================
#
# [Plotter] Generating Weighted Minkowski Envelopes...

# %%
task_uni = AMGF["stoch_unicycle"]
result_uni = TaskRunner.run(task_uni)
plot = Visualizer.plot(result_uni, title="Modified Unicycle: 10k Traces")
# Out:
# [TaskRunner] Initializing stochastic task: Nonlinear Unicycle
# [Monte Carlo] Simulating 10000 traces (0.0->4.0) with dt=0.001...
#
# ======================================================================
# --- Starting STOCHASTIC Test: Nonlinear Unicycle ---
# Mode: single_step
# System: [(-0.1*px*cos(theta) - 0.1*py*sin(theta))*cos(theta), (-0.1*px*cos(theta) - 0.1*py*sin(theta))*sin(theta), -0.1*theta]
# Fixed Step Mode: False, Preconditioning: QR
# Initial Set: [Interval([4.90000000000000, 5.10000000000000]), Interval([4.90000000000000, 5.10000000000000]), Interval([-2.00000000000000, -1.89999999999999])]
# Time: [0, 4.0], Step: 0.05, Order: 6
# Stochastic Config: Delta=0.001
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 45.4300 seconds
# Computed 81 segments.
# ----------------------------------------------------------------------
#
# Final Reachable Set Bounds (t_end)
# Dim        | Deterministic Interval         | Stochastic box overapprox (1-δ)
# ------------------------------------------------------------------------------------------
# px         | [   4.65785,    5.02889]       | [   1.55674,    8.13001]
# py         | [   3.24834,    3.50495]       | [   0.14723,    6.60606]
# theta      | [  -1.34064,   -1.27361]       | [  -4.44175,    1.82750]
#
# Validation Statistics
# Metric: max_k ||X_t^k - x_t^k|| (paired deterministic trajectories)
#   Status: PASS
#   Max Theoretical Bound (r): 3.101112
#   Max Empirical Deviation:   1.014025
#   Safety Margin:             2.087087
#   Trajectory Violations:     0 steps had outliers (100% enclosed at sampled times)
# ======================================================================
#
# [Plotter] Generating Euclidean Minkowski Envelopes...
