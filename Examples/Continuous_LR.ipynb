# %%
from Benchmarks import INTLAB_benchmarks
from TERA.Workbench.Task import TaskRunner
from TERA.Workbench.Visualizer import Visualizer

intlab = INTLAB_benchmarks.get_intlab_benchmarks()

# %% [markdown]
# ## Example II: Lotka Volterra

# %%
task_lv = intlab["intlab_cont_lotka_volterra"]
result_lv = TaskRunner.run(task_lv, progress_bar=True)
plot = Visualizer.plot(result_lv, dims=(0, 1), title="Lotka Volterra: Phase Portrait")
timeplot = Visualizer.plot(result_lv, mode="time", y_idx=1, title="Lotka Volterra: y over Time")
# Out:
# [TaskRunner] Initializing continuous task: Lotka-Volterra (INTLAB demo Example II)
# L-R Reachability:   0%|          | 0/5.5 [00:00<?, ?it/s]
# ...
# --- Starting CONTINUOUS Test: Lotka-Volterra (INTLAB demo Example II) ---
# Mode: left_right
# System: [-2.0*y1*(y2 - 1.0), (y1 - 1.0)*y2]
# Fixed Step Mode: False, Preconditioning: QR
# Initial Set: [Interval([0.949999999999999, 1.05000000000001]), Interval([2.95000000000000, 3.05000000000000])]
# Time: [0, 5.5], Step: 0.03, Order: 8
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 105.1483 seconds
# Computed 41 segments.
# ----------------------------------------------------------------------
#
# --- FINAL STATE VALIDATION ---
# y1         | [0.744748, 1.182186] (Width: 0.437438)
# y2         | [2.925113, 3.064425] (Width: 0.139312)
#
# Comparing against expected benchmarks...
#
#   PASS (Loose): y1 (Encloses expected)
# ...

# %% [markdown]
# ## Example III: Lorenz System

# %%
task_lz = intlab["intlab_cont_lorenz"]
result_lz = TaskRunner.run(task_lz, progress_bar=True)
plot = Visualizer.plot(result_lz, dims=(0, 1), title="Lorenz System: Phase Portrait")
timeplot = Visualizer.plot(result_lz, mode="time", y_idx=1, title="Lorenz System: y over Time")

# %% [markdown]
# ## Example IV: Quadratic Model

# %%
task_q = intlab["intlab_cont_quadratic"]
result_q = TaskRunner.run(task_q, progress_bar=True)
plot = Visualizer.plot(result_q, dims=(0, 1), title="Quadratic Model: Phase Portrait")
# Out:
# [TaskRunner] Initializing continuous task: Quadratic Model (INTLAB demo Example IV)
# L-R Reachability:   0%|          | 0/6.0 [00:00<?, ?it/s]
# ...
# --- Starting CONTINUOUS Test: Quadratic Model (INTLAB demo Example IV) ---
# Mode: left_right
# System: [y2, y1^2]
# Fixed Step Mode: False, Preconditioning: QR
# Initial Set: [Interval([0.949999999999999, 1.05000000000001]), Interval([-1.05000000000001, -0.949999999999999])]
# Time: [0, 6.0], Step: 0.02, Order: 10
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 88.4697 seconds
# Computed 34 segments.
# ----------------------------------------------------------------------
#
# --- FINAL STATE VALIDATION ---
# y1         | [-0.272091, 1.053144] (Width: 1.325236)
# y2         | [0.123341, 1.159481] (Width: 1.036141)
#
# Comparing against expected benchmarks...
#
#   PASS (Loose): y1 (Encloses expected)
#     Computed: Interval([-0.272091454982859, 1.05314426949963])
# ...

# %% [markdown]
# ## Example VI: Kepler Asteroid Motion
# note: INTLAB says this takes >4 hours to run

# %%
task_kep = intlab["intlab_cont_kepler"]
result_kep = TaskRunner.run(task_kep, progress_bar=True)
plot_kep = Visualizer.plot(result_kep, dims=(0,1), title="Kepler Asteroid Motion")
