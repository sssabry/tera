# %%
from Benchmarks import C2E2_benchmarks
from TERA.Workbench.Task import TaskRunner
from TERA.Workbench.Visualizer import Visualizer

tasks = C2E2_benchmarks.get_c2e2_hybrid()

# %% [markdown]
# ## C2E2: Examples

# %% [markdown]
# ### Cardiac Cell

# %%
task = tasks["hybrid_cardiac"]

result = TaskRunner.run(task, progress_bar=True)

mode_colors = {'stimOn': 'magenta', 'stimOff': 'blue'}
plot = Visualizer.plot(result, dims=(0,1), mode="time", mode_colors=mode_colors, y_idx=0, title="Cardiac Cell: u over Time", filled=True)

# %% [markdown]
# ### Linear Thermometer

# %%
task = tasks["hybrid_linthermo_v1"]
result = TaskRunner.run(task, progress_bar=True)

mode_colors = {'heating': 'red', 'cooling': 'blue'}
plot = Visualizer.plot(result, mode="time", mode_colors=mode_colors, y_idx=0, title="Thermostat: x over Time", filled=True)
# Out:
# [TaskRunner] Initializing hybrid task: C2E2 Linear Thermostat (Property1)
# Hybrid Reachability Analysis:   0%|          | 0/3.5 [00:00<?, ?it/s]
# ...
# --- Starting HYBRID Test: C2E2 Linear Thermostat (Property1) ---
# Mode: single_step
# System: None
# Fixed Step Mode: False, Preconditioning: ID
# Initial Set: [Interval([68.0000000000000, 69.0000000000000])]
# Time: [0, 3.5], Step: 0.01, Order: 10
# Hybrid Config: Max Jumps=20, Methods: Intersection=domain_contraction, Aggregation=PCA
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 110.9005 seconds
# Computed 253 segments.
# ----------------------------------------------------------------------
#
# --- SAFETY VERIFICATION ---
#   [!] BREACH DETECTED on t ∈ [3.2899, 3.3099]
#   Reason: Unsafe set active from t=0.0000 (violation may occur within this segment)
# Hybrid Path Summary:
#   Total Segments: 253
#   Modes Traversed: cooling, heating
#   Final Horizon: 3.5000s
# ...

# %%
task = tasks["hybrid_linthermo_v2"]
result = TaskRunner.run(task, progress_bar=True)

mode_colors = {'heating': 'red', 'cooling': 'blue'}
plot = Visualizer.plot(result, mode="time", mode_colors=mode_colors, y_idx=0, title="Thermostat: x over Time", filled=True)
# Out:
# [TaskRunner] Initializing hybrid task: C2E2 Linear Thermostat (P2)
# Hybrid Reachability Analysis:   0%|          | 0/3.5 [00:00<?, ?it/s]
# [MS][EXIT-SLICE] mode=cooling t_abs=[2.40875,2.40938] t_loc=[0,0.000625]
# [HR][FLOW] mode=cooling status=BOUNDARY_EVENT n_seg=1429 boundary=True
# [HR][ANALYZE] mode=cooling urgent=True n_tr=1
# [HR][ENABLED] mode=cooling enabled=1 truncate=72
# [MS][EXIT-SLICE] mode=heating t_abs=[3.22,3.22063] t_loc=[0,0.000625]
# [HR][FLOW] mode=heating status=BOUNDARY_EVENT n_seg=821 boundary=True
# [HR][ANALYZE] mode=heating urgent=True n_tr=1
# [HR][ENABLED] mode=heating enabled=1 truncate=172
# [HR][FLOW] mode=cooling status=SUCCESS n_seg=110 boundary=False
# [HR][ANALYZE] mode=cooling urgent=True n_tr=1
# [HR][ENABLED] mode=cooling enabled=0 truncate=None
#
# ...
# --- Starting HYBRID Test: C2E2 Linear Thermostat (P2) ---
# Mode: single_step
# System: None
# Fixed Step Mode: False, Preconditioning: ID
# ...
