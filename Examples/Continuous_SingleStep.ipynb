# %%
from Benchmarks import FLOWSTAR_benchmarks, JUILIAREACH_benchmarks
from TERA.Workbench.Task import TaskRunner
from TERA.Workbench.Visualizer import Visualizer

tasks = FLOWSTAR_benchmarks.get_chen_continuous()

# %% [markdown]
# ## Xin Chen (Flowstar): Thesis Examples

# %% [markdown]
# ### Example 3.3.9: Jet Engine

# %%
result_lv = TaskRunner.run(tasks["cont_jet_engine"])
plot = Visualizer.plot(result_lv, title="Jet Engine: Phase Portrait")
# Out:
# [TaskRunner] Initializing continuous task: Jet Engine (Example 3.3.9)
#
# ======================================================================
# --- Starting CONTINUOUS Test: Jet Engine (Example 3.3.9) ---
# Mode: single_step
# System: [-0.5*x^3 - 1.5*x^2 - y - 0.5, 3*x - y]
# Fixed Step Mode: True, Preconditioning: ID
# Initial Set: [Interval([0.900000000000000, 1.10000000000001]), Interval([0.900000000000000, 1.10000000000001])]
# Time: [0, 10.0], Step: 0.02, Order: 4
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 9.6939 seconds
# Computed 501 segments.
# ----------------------------------------------------------------------

# %% [markdown]
# ### Example 3.3.11: Lotka Volterra

# %%
result_lv = TaskRunner.run(tasks["cont_lotka_volterra"])
plot = Visualizer.plot(result_lv, title="Lotka-Volterra: Phase Portrait")
# Out:
# [TaskRunner] Initializing continuous task: Lotka-Volterra (Example 3.3.11)
#
# ======================================================================
# --- Starting CONTINUOUS Test: Lotka-Volterra (Example 3.3.11) ---
# Mode: single_step
# System: [-x*y + 1.5*x, x*y - 3*y]
# Fixed Step Mode: True, Preconditioning: ID
# Initial Set: [Interval([4.95000000000000, 5.05000000000000]), Interval([1.94999999999999, 2.05000000000000])]
# Time: [0, 4.0], Step: 0.01, Order: 5
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 9.6013 seconds
# Computed 401 segments.
# ----------------------------------------------------------------------
#
# --- FINAL STATE VALIDATION ---
# x          | [1.599950, 1.699950] (Width: 0.100000)
# y          | [2.039988, 2.139988] (Width: 0.100000)
#
# Comparing against expected benchmarks...
#
#   PASS (Loose): x (Encloses expected)
#     Computed: Interval([1.59995003485644, 1.69995003485645])
#     Expected: Interval([1.61147354201700, 1.68842650314001])
#     Diff: L=1.15e-02, U=1.15e-02
#
#   PASS (Loose): y (Encloses expected)
#     Computed: Interval([2.03998785882132, 2.13998785882134])
#     Expected: Interval([2.04388040336199, 2.13609525123800])
#     Diff: L=3.89e-03, U=3.89e-03
#
# SUMMARY: Validation PASSED
# ======================================================================

# %% [markdown]
# ### Example 3.4.2: Lorenz System

# %%
result_lv = TaskRunner.run(tasks["cont_lorenz_chen"], progress_bar=True)
plot = Visualizer.plot(result_lv, title="Lorenz System: Phase Portrait")

# %% [markdown]
# ### Example 3.4.3: Rossler Attractor

# %%
result_lv = TaskRunner.run(tasks["cont_rossler"], progress_bar=True)
plot = Visualizer.plot(result_lv, title="Rossler Attractor: Phase Portrait")

# %% [markdown]
# ### Example 5.2.1: Van der Pol

# %%
result_lv = TaskRunner.run(tasks["cont_vanderpol"])
plot = Visualizer.plot(result_lv, title="Van Der Pol: Phase Portrait")
# Out:
# [TaskRunner] Initializing continuous task: Van der Pol (Example 5.2.1)
#
# ======================================================================
# --- Starting CONTINUOUS Test: Van der Pol (Example 5.2.1) ---
# Mode: single_step
# System: [y, -(x^2 - 1)*y - x]
# Fixed Step Mode: True, Preconditioning: ID
# Initial Set: [Interval([1.25000000000000, 1.55000000000001]), Interval([2.35000000000000, 2.45000000000001])]
# Time: [0, 7.0], Step: 0.02, Order: 5
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 7.7090 seconds
# Computed 351 segments.
# ----------------------------------------------------------------------

# %% [markdown]
# ### Example 5.2.4: Biological Model I

# %%
result_lv = TaskRunner.run(tasks["cont_bio"])
plot = Visualizer.plot(result_lv, title="Biological Model: Phase Portrait")
# Out:
# [TaskRunner] Initializing continuous task: Biological Model I (Example 5.2.4)
#
# ======================================================================
# --- Starting CONTINUOUS Test: Biological Model I (Example 5.2.4) ---
# Mode: single_step
# System: [5*x3*x4 - 0.4*x1, 0.4*x1 - x2, -5*x3*x4 + x2, -5*x3*x4 + 5*x5*x6, 5*x3*x4 - 5*x5*x6, -5*x5*x6 + 0.5*x7, 5*x5*x6 - 0.5*x7]
# Fixed Step Mode: True, Preconditioning: ID
# Initial Set: [Interval([0.989999999999999, 1.01000000000001]), Interval([0.989999999999999, 1.01000000000001]), Interval([0.989999999999999, 1.01000000000001]), Interval([0.989999999999999, 1.01000000000001]), Interval([0.989999999999999, 1.01000000000001]), Interval([0.989999999999999, 1.01000000000001]), Interval([0.989999999999999, 1.01000000000001])]
# Time: [0, 2.0], Step: 0.01, Order: 4
# ----------------------------------------------------------------------
# STATUS: SUCCESS. Total computation time: 27.2311 seconds
# Computed 200 segments.
# ----------------------------------------------------------------------

# %% [markdown]
# ## JuliaReach: Examples

# %%
tasks = JUILIAREACH_benchmarks.get_juliareach_benchmarks()

# %%
duffing_osc = tasks["juliareach_cont_duffing"]
result_lv = TaskRunner.run(duffing_osc, progress_bar=True)
plot = Visualizer.plot(result_lv, title="Duffing Oscillator: Phase Portrait")
